# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Utility

# %%
# Define the range of interest rates (1% to 10%)
interest_rates = np.arange(1, 11)

# Define the range of years (1 to 30)
years = np.arange(1, 31)

# Create a utility matrix using the formula (1 + interest_rates / 100) ^ years
original_matrix = np.power((1 + interest_rates / 100)[:, np.newaxis], years)

# Invert the matrix by taking the reciprocal of each element and round off to 2 decimals
inverse_matrix = np.round(1 / original_matrix, 4)

# Create a pandas DataFrame for the original matrix and round off to 2 decimals
original_df = pd.DataFrame(np.round(original_matrix, 4), index=interest_rates, columns=years)

# Create a pandas DataFrame for the inverse matrix
inverse_df = pd.DataFrame(inverse_matrix, index=interest_rates, columns=years)

original_df.to_csv("bank_utility.csv")
inverse_df.to_csv("person_utility.csv")

# %%
# Print the original and inverse DataFrames
print("Original Matrix:")
transposed_df_BMatrix = original_df.transpose()
# Out:
# Original Matrix:

# %%
print("\nInverse Matrix:")
transposed_df_IMatrix = inverse_df.transpose()
transposed_df_IMatrix
# Out:
# Inverse Matrix:
#         1       2       3       4       5       6       7       8       9   \
# 1   0.9901  0.9804  0.9709  0.9615  0.9524  0.9434  0.9346  0.9259  0.9174
# 2   0.9803  0.9612  0.9426  0.9246  0.9070  0.8900  0.8734  0.8573  0.8417
# 3   0.9706  0.9423  0.9151  0.8890  0.8638  0.8396  0.8163  0.7938  0.7722
# 4   0.9610  0.9238  0.8885  0.8548  0.8227  0.7921  0.7629  0.7350  0.7084
# 5   0.9515  0.9057  0.8626  0.8219  0.7835  0.7473  0.7130  0.6806  0.6499
# 6   0.9420  0.8880  0.8375  0.7903  0.7462  0.7050  0.6663  0.6302  0.5963
# 7   0.9327  0.8706  0.8131  0.7599  0.7107  0.6651  0.6227  0.5835  0.5470
# 8   0.9235  0.8535  0.7894  0.7307  0.6768  0.6274  0.5820  0.5403  0.5019
# 9   0.9143  0.8368  0.7664  0.7026  0.6446  0.5919  0.5439  0.5002  0.4604
# 10  0.9053  0.8203  0.7441  0.6756  0.6139  0.5584  0.5083  0.4632  0.4224
# 11  0.8963  0.8043  0.7224  0.6496  0.5847  0.5268  0.4751  0.4289  0.3875
# 12  0.8874  0.7885  0.7014  0.6246  0.5568  0.4970  0.4440  0.3971  0.3555
# 13  0.8787  0.7730  0.6810  0.6006  0.5303  0.4688  0.4150  0.3677  0.3262
# 14  0.8700  0.7579  0.6611  0.5775  0.5051  0.4423  0.3878  0.3405  0.2992
# 15  0.8613  0.7430  0.6419  0.5553  0.4810  0.4173  0.3624  0.3152  0.2745
# 16  0.8528  0.7284  0.6232  0.5339  0.4581  0.3936  0.3387  0.2919  0.2519
# 17  0.8444  0.7142  0.6050  0.5134  0.4363  0.3714  0.3166  0.2703  0.2311
# 18  0.8360  0.7002  0.5874  0.4936  0.4155  0.3503  0.2959  0.2502  0.2120
# 19  0.8277  0.6864  0.5703  0.4746  0.3957  0.3305  0.2765  0.2317  0.1945
# 20  0.8195  0.6730  0.5537  0.4564  0.3769  0.3118  0.2584  0.2145  0.1784
# 21  0.8114  0.6598  0.5375  0.4388  0.3589  0.2942  0.2415  0.1987  0.1637
# 22  0.8034  0.6468  0.5219  0.4220  0.3418  0.2775  0.2257  0.1839  0.1502
# 23  0.7954  0.6342  0.5067  0.4057  0.3256  0.2618  0.2109  0.1703  0.1378
# 24  0.7876  0.6217  0.4919  0.3901  0.3101  0.2470  0.1971  0.1577  0.1264
# 25  0.7798  0.6095  0.4776  0.3751  0.2953  0.2330  0.1842  0.1460  0.1160
# 26  0.7720  0.5976  0.4637  0.3607  0.2812  0.2198  0.1722  0.1352  0.1064
# 27  0.7644  0.5859  0.4502  0.3468  0.2678  0.2074  0.1609  0.1252  0.0976
# 28  0.7568  0.5744  0.4371  0.3335  0.2551  0.1956  0.1504  0.1159  0.0895
# 29  0.7493  0.5631  0.4243  0.3207  0.2429  0.1846  0.1406  0.1073  0.0822
# 30  0.7419  0.5521  0.4120  0.3083  0.2314  0.1741  0.1314  0.0994  0.0754
#
#         10
# 1   0.9091
# 2   0.8264
# 3   0.7513
# 4   0.6830
# 5   0.6209
# 6   0.5645
# 7   0.5132
# 8   0.4665
# 9   0.4241
# 10  0.3855
# 11  0.3505
# 12  0.3186
# 13  0.2897
# 14  0.2633
# 15  0.2394
# 16  0.2176
# 17  0.1978
# 18  0.1799
# 19  0.1635
# 20  0.1486
# 21  0.1351
# 22  0.1228
# 23  0.1117
# 24  0.1015
# 25  0.0923
# 26  0.0839
# 27  0.0763
# 28  0.0693
# 29  0.0630
# 30  0.0573

# %% [markdown]
# ## probability

# %%
prob = pd.read_csv('prob.csv')
prob
# Out:
#    Interest Rate  Probability
# 0            1.0     0.217391
# 1            2.0     0.312253
# 2            3.0     0.256917
# 3            4.0     0.067194
# 4            5.0     0.047431
# 5            6.0     0.063241
# 6            7.0     0.023715
# 7            8.0     0.011858
# 8            9.0     0.000000
# 9           10.0     0.000000

# %% [markdown]
# ## Decsion matrix

# %%
# Extract the 'Probability' column from Matrix B as a NumPy array
matrix_b_probability = prob['Probability'].values.reshape(-1, 1)
matrix_b_probability_transposed = prob['Probability'].values.reshape(1, -1)
# print (matrix_b_probability_transposed)

# Perform matrix multiplication
result_matrix_ = np.dot(transposed_df_IMatrix , inverse_df)

# Display the result
print(result_matrix)
# Out:
# [[0.97339762 0.94772647 0.9229154  0.89900274 0.87589997 0.85358652
#   0.83202526 0.81116517 0.79100193 0.77149204 0.75263986 0.73437385
#   0.71671219 0.6996023  0.68300744 0.6669351  0.65140348 0.63630347
#   0.62164932 0.60748726 0.59370505 0.58035248 0.56740504 0.55480781
#   0.54258883 0.53072243 0.5192082  0.50799792 0.49708171 0.48652361]]

# %%
print("\nMatrix B:")
print(inverse_df)

print("\nTransposed Probability Matrix (Matrix B):")
print(matrix_b_probability_transposed)

print("\nIntermediate Steps:")

for i in range(len(matrix_b_probability_transposed)):
    print(f"\nRow {i + 1} of Result Matrix:")
    print(f"Matrix A (Row {i + 1}): {inverse_df.values[i]}")
    print(f"Matrix B (Transposed): {matrix_b_probability_transposed.flatten()}")
    print(f"Dot Product: {np.dot(inverse_df.values[i], matrix_b_probability_transposed.flatten())}")
    print(f"Result Matrix (Row {i + 1}): {result_matrix[i]}")
    print("-" * 30)

# Final Result
print("\nFinal Result Matrix:")
print(result_matrix)
# Out:
# Matrix B:
#         1       2       3       4       5       6       7       8       9   \
# 1   0.9901  0.9803  0.9706  0.9610  0.9515  0.9420  0.9327  0.9235  0.9143
# 2   0.9804  0.9612  0.9423  0.9238  0.9057  0.8880  0.8706  0.8535  0.8368
# 3   0.9709  0.9426  0.9151  0.8885  0.8626  0.8375  0.8131  0.7894  0.7664
# 4   0.9615  0.9246  0.8890  0.8548  0.8219  0.7903  0.7599  0.7307  0.7026
# 5   0.9524  0.9070  0.8638  0.8227  0.7835  0.7462  0.7107  0.6768  0.6446
# 6   0.9434  0.8900  0.8396  0.7921  0.7473  0.7050  0.6651  0.6274  0.5919
# 7   0.9346  0.8734  0.8163  0.7629  0.7130  0.6663  0.6227  0.5820  0.5439
# 8   0.9259  0.8573  0.7938  0.7350  0.6806  0.6302  0.5835  0.5403  0.5002
# 9   0.9174  0.8417  0.7722  0.7084  0.6499  0.5963  0.5470  0.5019  0.4604
# 10  0.9091  0.8264  0.7513  0.6830  0.6209  0.5645  0.5132  0.4665  0.4241
#
#         10  ...      21      22      23      24      25      26      27  \
# 1   0.9053  ...  0.8114  0.8034  0.7954  0.7876  0.7798  0.7720  0.7644
# 2   0.8203  ...  0.6598  0.6468  0.6342  0.6217  0.6095  0.5976  0.5859
# 3   0.7441  ...  0.5375  0.5219  0.5067  0.4919  0.4776  0.4637  0.4502
# 4   0.6756  ...  0.4388  0.4220  0.4057  0.3901  0.3751  0.3607  0.3468
# 5   0.6139  ...  0.3589  0.3418  0.3256  0.3101  0.2953  0.2812  0.2678
# 6   0.5584  ...  0.2942  0.2775  0.2618  0.2470  0.2330  0.2198  0.2074
# 7   0.5083  ...  0.2415  0.2257  0.2109  0.1971  0.1842  0.1722  0.1609
# 8   0.4632  ...  0.1987  0.1839  0.1703  0.1577  0.1460  0.1352  0.1252
# 9   0.4224  ...  0.1637  0.1502  0.1378  0.1264  0.1160  0.1064  0.0976
# 10  0.3855  ...  0.1351  0.1228  0.1117  0.1015  0.0923  0.0839  0.0763
#
#         28      29      30
# 1   0.7568  0.7493  0.7419
# 2   0.5744  0.5631  0.5521
# 3   0.4371  0.4243  0.4120
# 4   0.3335  0.3207  0.3083
# 5   0.2551  0.2429  0.2314
# 6   0.1956  0.1846  0.1741
# 7   0.1504  0.1406  0.1314
# 8   0.1159  0.1073  0.0994
# 9   0.0895  0.0822  0.0754
# 10  0.0693  0.0630  0.0573
#
# [10 rows x 30 columns]
#
# Transposed Probability Matrix (Matrix B):
# [[0.217391 0.312253 0.256917 0.067194 0.047431 0.063241 0.023715 0.011858
#   0.       0.      ]]
#
# Intermediate Steps:
#
# Row 1 of Result Matrix:
# Matrix A (Row 1): [0.9901 0.9803 0.9706 0.961  0.9515 0.942  0.9327 0.9235 0.9143 0.9053
#  0.8963 0.8874 0.8787 0.87   0.8613 0.8528 0.8444 0.836  0.8277 0.8195
#  0.8114 0.8034 0.7954 0.7876 0.7798 0.772  0.7644 0.7568 0.7493 0.7419]
# Matrix B (Transposed): [0.217391 0.312253 0.256917 0.067194 0.047431 0.063241 0.023715 0.011858
#  0.       0.      ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\even\OneDrive\Skrivebord\ADA501\Prosjekt\ada511.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/even/OneDrive/Skrivebord/ADA501/Prosjekt/ada511.ipynb#X35sZmlsZQ%3D%3D?line=10'>11</a> print(f"Matrix A (Row {i + 1}): {inverse_df.values[i]}")
#      <a href='vscode-notebook-cell:/c%3A/Users/even/OneDrive/Skrivebord/ADA501/Prosjekt/ada511.ipynb#X35sZmlsZQ%3D%3D?line=11'>12</a> print(f"Matrix B (Transposed): {matrix_b_probability_transposed.flatten()}")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/even/OneDrive/Skrivebord/ADA501/Prosjekt/ada511.ipynb#X35sZmlsZQ%3D%3D?line=12'>13</a> print(f"Dot Product: {np.dot(inverse_df.values[i], matrix_b_probability_transposed.flatten())}")
#      <a href='vscode-notebook-cell:/c%3A/Users/even/OneDrive/Skrivebord/ADA501/Prosjekt/ada511.ipynb#X35sZmlsZQ%3D%3D?line=13'>14</a> print(f"Result Matrix (Row {i + 1}): {result_matrix[i]}")
#      <a href='vscode-notebook-cell:/c%3A/Users/even/OneDrive/Skrivebord/ADA501/Prosjekt/ada511.ipynb#X35sZmlsZQ%3D%3D?line=14'>15</a> print("-" * 30)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# ValueError: shapes (30,) and (10,) not aligned: 30 (dim 0) != 10 (dim 0)
